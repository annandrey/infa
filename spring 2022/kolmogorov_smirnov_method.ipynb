# %%
from scipy import stats
import pandas
resist_distrib = pandas.read_csv("experiments_gauss.csv")
resist_distrib['experiments_gauss'].plot(kind='bar')
resist_distrib.plot.kde()
print(stats.kstest(resist_distrib, 'norm', (resist_distrib.mean(), resist_distrib.std()), N=len(resist_distrib)))
# Out:
# KstestResult(statistic=0.9990000239810742, pvalue=1.997603301011078e-150)
